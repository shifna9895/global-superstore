# %% [markdown]
# <a href="https://colab.research.google.com/github/shifna9895/global-superstore/blob/main/global_superstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Global Superstore**
#
# The Global Superstore dataset is a popular sample dataset often used for data analysis and visualization exercises. It generally includes the following key fields:
#
# 1. *Order ID*: Unique identifier for each order.
# 2. *Order Date*: Date when the order was placed.
# 3. *Ship Date*: Date when the order was shipped.
# 4. *Ship Mode*: The shipping method used (e.g., Standard Class, Second Class, etc.).
# 5. *Customer ID*: Unique identifier for each customer.
# 6. *Customer Name*: Name of the customer.
# 7. *Segment*: Customer segment (e.g., Consumer, Corporate, Home Office).
# 8. *Country*: Country where the customer is located.
# 9. *City*: City where the customer is located.
# 10. *State*: State where the customer is located.
# 11. *Postal Code*: Postal code of the customer's address.
# 12. *Category*: Product category (e.g., Furniture, Office Supplies, Technology).
# 13. *Sub-Category*: More specific category within the broader category.
# 14. *Product Name*: Name of the product.
# 15. *Sales*: Sales amount for the order.
# 16. *Quantity*: Quantity of products ordered.
# 17. *Discount*: Discount applied to the order.
# 18. *Profit*: Profit made on the order.
#
# This dataset is used to analyze sales performance, customer behavior, and other

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('global_superstore.xlsx')

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.head(10)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5   22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 8   40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9   36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# ...

# %%
df.tail(5)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.size
# Out:
# 1230960

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780608
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.describe(include='object')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
df.describe(include='all')
# Out:
#              Row ID                  Order ID                     Order Date  \
# count   51290.00000                     51290                          51290
# unique          NaN                     25728                            NaN
# top             NaN  CA-2015-SV20365140-42268                            NaN
# freq            NaN                        14                            NaN
# mean    25645.50000                       NaN  2014-05-11 21:26:49.155780608
# min         1.00000                       NaN            2012-01-01 00:00:00
# 25%     12823.25000                       NaN            2013-06-19 00:00:00
# 50%     25645.50000                       NaN            2014-07-08 00:00:00
# 75%     38467.75000                       NaN            2015-05-22 00:00:00
# max     51290.00000                       NaN            2015-12-31 00:00:00
# std     14806.29199                       NaN                            NaN
#
# ...

# %%
df.describe(include='all').T
# Out:
#                   count unique                       top   freq  \
# Row ID          51290.0    NaN                       NaN    NaN
# Order ID          51290  25728  CA-2015-SV20365140-42268     14
# Order Date        51290    NaN                       NaN    NaN
# Ship Date         51290    NaN                       NaN    NaN
# Ship Mode         51290      4            Standard Class  30775
# Customer ID       51290  17415              SV-203651406     26
# Customer Name     51290    796           Muhammed Yedwab    108
# Segment           51290      3                  Consumer  26518
# Postal Code      9994.0    NaN                       NaN    NaN
# City              51290   3650             New York City    915
# State             51290   1102                California   2001
# Country           51290    165             United States   9994
# Region            51290     23            Western Europe   5883
# Market            51290      5              Asia Pacific  14302
# ...

# %% [markdown]
# **CHECKING DUPLICATES**

# %%
df.duplicated(subset=['Customer ID','City']).sum()
# Out:
# 26337

# %%
df.duplicated(subset=['Customer ID','Product ID']).sum()
# Out:
# 118

# %%
df1=df[df.duplicated(subset=['Customer ID','Product ID'])]
df1
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 143     31649  CA-2014-AB10060140-41884 2014-09-02 2014-09-04     First Class
# 2628    40081  US-2015-AS10630140-42081 2015-03-18 2015-03-24  Standard Class
# 4257    33490  CA-2014-AP10915140-41984 2014-12-11 2014-12-18  Standard Class
# 4892    10287   US-2014-DN1369018-41688 2014-02-18 2014-02-22  Standard Class
# 5091     2377   MX-2013-AG1090082-41398 2013-05-04 2013-05-09  Standard Class
# ...       ...                       ...        ...        ...             ...
# 50428   10001   US-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50611      11   MX-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50963   38356  CA-2014-WB21850140-41985 2014-12-12 2014-12-12        Same Day
# 51017   10091   US-2012-KT1646518-41017 2012-04-18 2012-04-24  Standard Class
# 51129   37507  CA-2015-YS21880140-42235 2015-08-19 2015-08-26  Standard Class
#
# ...

# %%
data_6 = { 'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Eve', 'Alice'],
        'Age': [24, 27, 22, 24, 29, 24],
      'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Chicago', 'New York'] }
df6=pd.DataFrame(data_6)

# %%
df6
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    Alice   24     New York
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df6.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df6.drop_duplicates()
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df_f=df6.drop_duplicates(keep='first')
df_f
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df_l=df6.drop_duplicates(keep='last')
df_l
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df_=df6.drop_duplicates(keep=False)
df_
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %% [markdown]
# **convert data types**

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df['Postal Code']=df['Postal Code'].astype(str)

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code               object
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# **FEATURE ENGINEERING**

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df[['Sales','Quantity']]
# Out:
#           Sales  Quantity
# 0       221.980         2
# 1      3709.395         9
# 2      5175.171         9
# 3      2892.510         5
# 4      2832.960         8
# ...         ...       ...
# 51285    65.100         5
# 51286    16.720         5
# 51287     8.560         2
# 51288    13.440         2
# 51289    61.380         3
#
# [51290 rows x 2 columns]

# %%
df['Total_Order_Value']=df['Sales']*df['Quantity']

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# create a feature that calculate the profit margin as the percentage of the total sales

# %%
df['Profit Margin'] = (df['Profit'] / df['Total_Order_Value']) * 100
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.drop('Profit Margin',axis=1)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# Create a feature that calculates the price of the product after applying the discount.

# %%
df['price_after_discount']=df['Sales']*(1-df['Discount'])
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# create a feature that shipping cost per unit sold

# %%
df['shipping_cost_perunit_sold']=df['Shipping Cost']/df['Quantity']

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Row ID                      51290 non-null  int64
#  1   Order ID                    51290 non-null  object
#  2   Order Date                  51290 non-null  datetime64[ns]
#  3   Ship Date                   51290 non-null  datetime64[ns]
#  4   Ship Mode                   51290 non-null  object
#  5   Customer ID                 51290 non-null  object
#  6   Customer Name               51290 non-null  object
#  7   Segment                     51290 non-null  object
#  8   Postal Code                 9994 non-null   float64
#  9   City                        51290 non-null  object
#  10  State                       51290 non-null  object
#  11  Country                     51290 non-null  object
#  12  Region                      51290 non-null  object
# ...

# %% [markdown]
# **EXTRACTING DATE AND TIME COMPONENTS**
#
# Extracting date and time components from date time objects

# %%
df['order_year']=df['Order Date'].dt.year

# %% [markdown]
# Extract the year from the 'Order date' to create a new feature indicating the in which the order is placed

# %%
df.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Category Sub-Category                               Product Name  \
# ...

# %% [markdown]
# Extract the month from the 'Order date' to create a new feature indicating the in which the order is placed

# %%
df['order_month']=df['Order Date'].dt.month

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Discount    Profit Shipping Cost Order Priority  \
# ...

# %%
df['order_month_name']=df['Order Date'].dt.month_name()

# %% [markdown]
# Extract the month name from the 'Order date' to create a new feature indicating the in which the order is placed

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Profit Shipping Cost Order Priority shipping_cost_perunit_sold  \
# ...

# %%
df['order_day']=df['Order Date'].dt.day

# %% [markdown]
# Extract the day from the 'Order date' to create a new feature indicating the in which the order is placed

# %%
df.tail()
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ... Sub-Category  \
# 51285           Kure  ...    Fasteners
# ...

# %%
df['order_day_name']=df['Order Date'].dt.day_name()

# %% [markdown]
# Extract the day name from the 'Order date' to create a new feature indicating the in which the order is placed

# %%
df.tail()
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...                                   Product Name  \
# ...

# %%
df['ship_year']=df['Ship Date'].dt.year
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Sub-Category                               Product Name     Sales  \
# ...

# %%
df['ship_month']=df['Ship Date'].dt.month
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Discount    Profit Shipping Cost Order Priority order_year order_month  \
# ...

# %%
df['ship_month_name']=df['Ship Date'].dt.month_name()
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Profit Shipping Cost Order Priority order_year order_month  \
# ...

# %%
df['ship_day']=df['Ship Date'].dt.day
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Shipping Cost Order Priority order_year order_month order_month_name  \
# ...

# %%
df['ship_day_name']=df['Ship Date'].dt.day_name()
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Order Priority order_year order_month order_month_name order_day  \
# ...

# %% [markdown]
# Create a new column for the order delivery time (difference b/w ship date and order date)

# %%
df['Delivery_time']=df['Ship Date']-df['Order Date']
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# **Display today's date**

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2024-08-21 08:29:20.178563

# %% [markdown]
# Create a feature that calculates the age of an order in days from the order date to today's date

# %%
df['oreder_age']=(datetime.datetime.now()-df['Order Date']).dt.days
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# Average Shipping Delay for Orders Placed in December

# %%
december_orders=df[df['Order Date'].dt.month==12]
december_orders
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# 19      49463   TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 26      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 30        220   US-2012-RR1952536-41270 2012-12-27 2012-12-29    Second Class
# 32      40977  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51250    8362   MX-2015-BG1169518-42360 2015-12-22 2015-12-24     First Class
# 51254   43851   RS-2015-DP3000108-42355 2015-12-17 2015-12-20    Second Class
# 51263    6367   MX-2012-BP1123082-41264 2012-12-21 2012-12-25  Standard Class
# 51278   10410   ES-2012-LR1703548-41245 2012-12-02 2012-12-02        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
#
# ...

# %%
avg_shipping_delay=december_orders['Delivery_time'].mean()
avg_shipping_delay
# Out:
# Timedelta('3 days 22:53:29.333546428')

# %%
data = { 'Timestamp': ['2024-07-24 14:45:00', '2024-07-25 16:30:00',
                                         '2024-07-26 08:20:00', '2024-07-27 12:15:00'] }
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#             Timestamp
# 0 2024-07-24 14:45:00
# 1 2024-07-25 16:30:00
# 2 2024-07-26 08:20:00
# 3 2024-07-27 12:15:00

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %% [markdown]
# To ensure your dates are in datetime format, you can use the pd.to_datetime() function in Pandas.

# %%
df1['Timestamp']=pd.to_datetime(df1['Timestamp'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df1['Timestamp']=(df1['Timestamp']).astype('datetime64[ns]')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df1['date']=df1['Timestamp'].dt.date
df1['year']=df1['Timestamp'].dt.year
df1['month']=df1['Timestamp'].dt.month
df1['month_name']=df1['Timestamp'].dt.month_name()
df1['day']=df1['Timestamp'].dt.day
df1['day_name']=df1['Timestamp'].dt.day_name()

# %%
df1['hour']=df1['Timestamp'].dt.hour
df1['minute']=df1['Timestamp'].dt.minute
df1['second']=df1['Timestamp'].dt.second

# %%
df1
# Out:
#             Timestamp        date  year  month month_name  day   day_name  \
# 0 2024-07-24 14:45:00  2024-07-24  2024      7       July   24  Wednesday
# 1 2024-07-25 16:30:00  2024-07-25  2024      7       July   25   Thursday
# 2 2024-07-26 08:20:00  2024-07-26  2024      7       July   26     Friday
# 3 2024-07-27 12:15:00  2024-07-27  2024      7       July   27   Saturday
#
#    hour  minute  second
# 0    14      45       0
# 1    16      30       0
# 2     8      20       0
# 3    12      15       0

# %% [markdown]
# **date_range**
#
# To generate a date range in Pandas, you can use the pd.date_range() function. This is useful for creating sequences of dates or for setting up a date index.
#
# You can specify the start date, end date, and frequency of the dates.
#
# Parameters:
# start: The start date of the range.
# end: The end date of the range.
# freq: The frequency of the dates ('D' for daily, 'W' for weekly, 'M' for monthly, etc.).

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01')

# %% [markdown]
# to create a date column with randomly includes starting and ending date

# %%
ds
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',freq='D')
ds
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',freq='M')
ds
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %% [markdown]
# 'periods' used for the controlling the frequency

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',periods=10)
ds
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-02-10 16:00:00',
#                '2020-03-22 08:00:00', '2020-05-02 00:00:00',
#                '2020-06-11 16:00:00', '2020-07-22 08:00:00',
#                '2020-09-01 00:00:00', '2020-10-11 16:00:00',
#                '2020-11-21 08:00:00', '2021-01-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# **REPLACE**

# %%
df['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'std'], dtype=object)
# array(['First Class', 'Second Class', 'Same Day', 'std'], dtype=object)

# %% [markdown]
# How can you replace all instances of the word 'Standard class' with 'std' in the 'ship mode' column

# %%
df['Ship Mode']=df['Ship Mode'].replace('Standard Class','std')

# %%
df['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'std'], dtype=object)

# %%
df['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Low'], dtype=object)

# %%
df['Order Priority']=df['Order Priority'].replace('Low','Standard')

# %%
df['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Standard'], dtype=object)

# %% [markdown]
# **FILTER & SORT**

# %%
df['Profit'].unique()
# Out:
# array([  62.1544, -288.765 ,  919.971 , ...,   22.0472,  -49.572 ,
#          -6.456 ])

# %%
#Filter the rows where profit is negative
data=df[df['Profit']<0]
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 16      39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25           std
# 30        220   US-2012-RR1952536-41270 2012-12-27 2012-12-29  Second Class
# 40      21316   ID-2014-JB1600059-41873 2014-08-22 2014-08-26           std
# ...       ...                       ...        ...        ...           ...
# 51260   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24           std
# 51266   27081  ID-2013-EK13795102-41496 2013-08-10 2013-08-11   First Class
# 51275   46231    ZA-2012-AS285147-40988 2012-03-20 2012-03-25           std
# 51277   46582   TU-2015-KF6285134-42337 2015-11-29 2015-11-30   First Class
# 51279   43818    NI-2012-PO886595-41159 2012-09-07 2012-09-09  Second Class
#
# ...

# %%
#Filter the rows where profit is negative and quantity is greaterthan 10
filter_rows=df[(df['Profit']<0) & (df['Quantity']>10)]
filter_rows
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 109     11743   IT-2014-VM2168591-41711 2014-03-13 2014-03-13      Same Day
# 289     43395  TU-2013-SF10200134-41417 2013-05-23 2013-05-26   First Class
# 298     16456  IT-2013-JD16060120-41515 2013-08-29 2013-09-01   First Class
# 362     29513   ID-2014-SN2056097-41896 2014-09-14 2014-09-14      Same Day
# 368     29552   IN-2015-SV2078559-42110 2015-04-16 2015-04-18  Second Class
# ...       ...                       ...        ...        ...           ...
# 46367    8903   US-2014-TB2119018-41727 2014-03-29 2014-03-31   First Class
# 48243   32342  CA-2015-SN20710140-42290 2015-10-13 2015-10-17           std
# 49090   19360  IT-2012-MC17590124-41055 2012-05-26 2012-05-29   First Class
# 50328    5131    US-2015-SS208755-42204 2015-07-19 2015-07-23           std
# 50773   40318  CA-2013-VP21760140-41593 2013-11-15 2013-11-20           std
#
# ...

# %%
#calculate the average sales of the these filtered rows
filter_rows['Sales'].mean()
# Out:
# 650.2714193333333

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %% [markdown]
# Filter data where category is furniture and profit is greaterthan 1000

# %%
df[(df['Category']=='Furniture') & (df['Profit']>1000)]
df.tail()
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19      Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10           std
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31  Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21           std
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26  Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...         Category Sub-Category  \
# ...

# %% [markdown]
# Filter the rows where product name contain word 'phone'

# %%
df['Product Name'].unique()
# Out:
# array(['Samsung Convoy 3', 'Novimex Executive Leather Armchair, Black',
#        'Nokia Smart Phone, with Caller ID', ...,
#        'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection',
#        'Hewlett-Packard Deskjet D4360 Printer', 'Cisco SPA 501G IP Phone'],
#       dtype=object)

# %%
df[df['Product Name'].str.contains('Phone')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28  Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31 2015-08-01   First Class
# ...       ...                       ...        ...        ...           ...
# 50805   31512  CA-2013-VW21775140-41275 2013-01-01 2013-01-08           std
# 50858    8089   US-2015-PS1904598-42349 2015-12-11 2015-12-16           std
# 50881   43296   PL-2012-DB2910103-41005 2012-04-06 2012-04-08  Second Class
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14           std
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31  Second Class
#
# ...

# %% [markdown]
# Modify the 'order priority ' column to label all orders with a profit below zero as urgent

# %%
df.loc[df['Profit']<0,'Order priority']='Urgent'
df['Order priority'].unique()
# Out:
# array(['nan', 'Urgent'], dtype=object)

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Category Sub-Category                               Product Name  \
# ...

# %% [markdown]
# How many rows have 'Urgent' as order priority

# %%
df[df['Order priority']=='Urgent'].shape[0]
# Out:
# 12544

# %% [markdown]
# anoter method: using len function

# %%
len(df[df['Order priority']=='Urgent'])
# Out:
# 12544

# %% [markdown]
# **SORTING**

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Order priority'],
#       dtype='object')

# %%
df['Sales'].sort_values(ascending=False)
# Out:
# 47114    22638.480
# 49003    17499.950
# 44248    13999.960
# 49940    11199.968
# 25238    10499.970
#            ...
# 24977        0.876
# 26588        0.852
# 33493        0.836
# 45391        0.556
# 51260        0.444
# Name: Sales, Length: 51290, dtype: float64

# %%
df[['Sales','Product Name']].sort_values(by='Sales',ascending=False)
# Out:
#            Sales                                       Product Name
# 47114  22638.480  Cisco TelePresence System EX90 Videoconferenci...
# 49003  17499.950              Canon imageCLASS 2200 Advanced Copier
# 44248  13999.960              Canon imageCLASS 2200 Advanced Copier
# 49940  11199.968              Canon imageCLASS 2200 Advanced Copier
# 25238  10499.970              Canon imageCLASS 2200 Advanced Copier
# ...          ...                                                ...
# 24977      0.876                                  Acco 3-Hole Punch
# 26588      0.852                      Avery Round Ring Poly Binders
# 33493      0.836  Avery Durable Slant Ring Binders With Label Ho...
# 45391      0.556           Acco Suede Grain Vinyl Round Ring Binder
# 51260      0.444  Hoover Replacement Belt for Commercial Guardsm...
#
# [51290 rows x 2 columns]

# %% [markdown]
# Sort the data set first by 'category' in ascending order and then by 'profit' in descending order

# %%
df[['Category','Profit']].sort_values(by=['Category','Profit'],ascending=[True,False])
# Out:
#          Category     Profit
# 334     Furniture  2316.5100
# 42      Furniture  2097.0300
# 192     Furniture  2071.4400
# 118     Furniture  1868.1300
# 940     Furniture  1622.8800
# ...           ...        ...
# 362    Technology -3009.4350
# 47527  Technology -3399.9800
# 23110  Technology -3839.9904
# 6591   Technology -4088.3760
# 11755  Technology -6599.9780
#
# [51290 rows x 2 columns]

# %% [markdown]
# How can you sort the dataset by quantity in descending order and then select the top 10 records

# %%
df['Quantity'].sort_values(ascending=False).head(10)
# Out:
# 7971     14
# 17405    14
# 40522    14
# 15388    14
# 33134    14
# 13398    14
# 17675    14
# 10107    14
# 2680     14
# 31397    14
# Name: Quantity, dtype: int64

# %% [markdown]
# Sort the dataset by 'order date' in ascending order

# %%
df['Order Date'].sort_values(ascending=True)
# Out:
# 22950   2012-01-01
# 43610   2012-01-01
# 25078   2012-01-01
# 31870   2012-01-01
# 31583   2012-01-01
#            ...
# 17379   2015-12-31
# 42870   2015-12-31
# 39873   2015-12-31
# 7908    2015-12-31
# 39602   2015-12-31
# Name: Order Date, Length: 51290, dtype: datetime64[ns]

# %% [markdown]
# Filter the dataset to include  only rows where the order date is between '2013-01-01' and '2014-12-31'?

# %%
df[(df['Order Date']>'2013-01-01') & (df['Order Date']< '2014-12-31')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# ...       ...                       ...        ...        ...           ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09      Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31   First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10           std
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21           std
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26  Second Class
#
# ...
